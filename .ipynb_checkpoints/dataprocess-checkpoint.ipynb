# %%
import json
from haralyzer import HarParser, HarPage
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # Extract websocket data from Har to JSON

# %%
class ProcHarData:
    
    def __init__(self,har_filename):
        self.harfile = har_filename
    
    def convHar2Json(self):
        with open(self.harfile, 'r') as f:
            har_parser = HarParser(json.loads(f.read()))

        data = har_parser.har_data
        ws_entries = []
        entries = []
        dict_data = {}
        for entry in har_parser.har_data["entries"]:
            if '_webSocketMessages' in entry.keys():
                ws_entries = entry['_webSocketMessages']
                break

        for ws_entry in ws_entries:    
            if ws_entry['data'].startswith("{"):
                data = json.loads(ws_entry['data'])
                if data['type'] == 3:
                    ws_entry['data'] = data
                    entries.append(ws_entry)
        dict_data['WS'] = entries
        json_filename = "data/data_" + datetime.now().strftime("%m-%d-%Y_%H:%M:%S") + ".json"
        with open(json_filename, 'w') as fp:
            json.dump(dict_data, fp)
        return json_filename


    def convJson2DF(self, json_filename=None):
        if json_filename:
            df = pd.read_json(json_filename)
        else:
            df = pd.read_json(self.convHar2Json())
        time = []
        duration = []
        for idx,row in df.iterrows():
            time.append(row['WS']['time'])
            durms = round(row['WS']['data']['data']['duration']/1000,2)
            duration.append(durms)
        df['DateTime'] = time
        df['TSDuration(ms)'] = duration
        df['DateTime'] = pd.to_datetime(df['DateTime'],unit='s')
        df = df.sort_values(by='DateTime')
        
        return df
    
    def plotTS(self,df1):
        
        fig, ax = plt.subplots(figsize=(12,5))
        meanDur = np.full(len(df1),df1.mean().values)
        df1.plot(figsize=(18,5),title='Tip Selection Duration(ms)',xlabel='Timesteps',ylabel='Duration(ns)',ax=ax)
        ax.plot(meanDur,'r')

        fig.show()

# %%
filename = 'data/10.2.8.177.har'
har = ProcHarData(filename)
df = har.convJson2DF()

df1 = df[['TSDuration(ms)']][:100]
print(df1)
har.plotTS(df1)
# Out:
#     TSDuration(ms)
# 0            42.78
# 1             2.44
# 2             9.47
# 3             4.47
# 4             3.34
# ..             ...
# 95            9.13
# 96            3.28
# 97            7.32
# 98            2.95
# 99            6.26
#
# [100 rows x 1 columns]

# %% [markdown]
# # Process locust perf data

# %%
class ProcLocustData:
    
    def __init__(self,locustdata_file):
        self.locustfile = locustdata_file
    
    
    def load2DF(self):
        """
        load data and return statistics dataframe.
        -----------------------
        Parameters:
            locustdata_file: string
                path and filename
        
        Returns:
            df_statics: DataFrame
                Statistics (mean values) dataframe of a specific task.
        -----------------------
        """
        df = pd.read_csv(self.locustfile)
        df.dropna(inplace=True)
        df = df.loc[(df['User Count'] % 10 == 0) & (df['User Count'] != 0)]
        
        return df
    
    
    def plotER(self,df,name):
        
        fig=plt.figure()

        ax1 = df[['Total Average Response Time']].plot(marker='*',legend=False)
        ax2 = df['Requests/s'].plot(secondary_y=True, marker='o')
        ax1.set_ylabel('Mean Response Time(ms)')
        ax2.set_ylabel('Requests/s')

        handles,labels = [],['E[R]','$\lambda$']
        for ax in [ax1,ax2]:
            for h,_ in zip(*ax.get_legend_handles_labels()):
                handles.append(h)

        plt.legend(handles,labels,loc='upper left')

        plt.title('Mean Response Time against User Count ({})'.format(name))
        plt.show()

# %%
def plotAll(filename):
    locust = ProcLocustData(filename)
    df = locust.load2DF()
    for name in df.Name.unique():
        df_task = df.loc[df['Name']==name]
        df_statics = df_task.groupby(by='User Count').mean()
        locust.plotER(df_statics,name)

# %%
filename = 'data/requests_full_history_1620626618.3389308 (1).csv'
plotAll(filename)

# %%
filename = 'data/requests_full_history_1620664510.9175324.csv'
plotAll(filename)

# %%
filename = 'data/requests_full_history_1620666204.3876286.csv'
plotAll(filename)

# %% [markdown]
# # Process DAGBench test data
#
# The following errors happened when rate reached 30: <br>
# tangle send error: FetchError: request to http://10.2.9.136:14265/ failed, reason: read ECONNRESET<br>
# tangle send error: FetchError: request to http://10.2.9.136:14265/ failed, reason: read ETIMEDOUT

# %%
import os
import glob
import pandas as pd
os.chdir("/home/sfan/github/tangleQ/data/dagbench/")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
tps_filenames, latency_filenames = [], []
for f in all_filenames:
    if 'tangle-throughput' in f:
        tps_filenames.append(f)
    elif 'tangle-latency' in f:
        latency_filenames.append(f)
combined_tps = pd.concat([pd.read_csv(f) for f in tps_filenames])
combined_tps.to_csv( "combined_throughput.csv", index=False, encoding='utf-8-sig')
combined_latency = pd.concat([pd.read_csv(f) for f in latency_filenames])
combined_latency.to_csv( "combined_latency.csv", index=False, encoding='utf-8-sig')

# %%
df_tps = pd.read_csv("combined_throughput.csv").sort_values(by='RATE')
df_latency = pd.read_csv("combined_latency.csv").sort_values(by='RATE')

# %%
fig, axs = plt.subplots(figsize=(15,4),nrows=1, ncols=3)
rps = np.arange(5, 45, 5)
axs[0].plot(rps, df_tps['TPS'].values, linestyle='--', color='r', marker='*',label='TPS')
axs[0].plot(rps, df_tps['RATE'].values, linestyle='--', color='blue', marker='+', label='Send Rate')
axs[0].set(xlabel='Requests Per Second', ylabel='tx/s', title='Throughput(TPS) under varing request rates')
axs[0].legend()

axs[1].plot(rps, df_tps['CTPS'].values, color='green', marker='>',label='CTPS')
axs[1].set(xlabel='Requests Per Second', ylabel='tx/s', title='CTPS under varing request rates')
axs[1].legend()

axs[2].plot(rps, df_latency['MIN'].values, color='b', marker='+', label='Minimum latency')
axs[2].plot(rps, df_latency['MAX'].values, color='blue', marker='>', label='Maximum latency')
axs[2].plot(rps, df_latency['AVERAGE'].values, color='green', marker='d', label='Average latency')
axs[2].set(xlabel='Requests per Second',ylabel='Latency (S)',title='Latency under varing request rates')
axs[2].legend()
fig.show()

# %%
import json
mean_lat, mean_prep, mean_send = [],[],[]
for rps in range(5, 45, 5):
    filename = 'time-{}.json'.format(rps)
    df = pd.read_json(filename).describe()
    mean_lat.append(df.latency['mean'])
    mean_prep.append(df.prepare_time['mean'])
    mean_send.append(df.send_time['mean'])

fig, axs = plt.subplots(figsize=(12,4), nrows=1, ncols=2)
rps = np.arange(5, 45, 5)
axs[0].plot(rps, mean_lat, linestyle='--', color='red', marker='*',label='average latency')
axs[0].plot(rps, mean_prep, linestyle='--', color='blue', marker='+', label='average prepare time')
axs[0].plot(rps, mean_send, linestyle='--', color='black', marker='>', label='avergae send time')
axs[0].set(xlabel='Requests Per Second', ylabel='Time (S)', title='Service time under varing request rates')
axs[0].legend()

x = np.arange(len(rps))  # the label locations
width = 0.27  # the width of the bars

rects1 = axs[1].bar(x - width, mean_lat, width, label='average latency')
rects2 = axs[1].bar(x, mean_prep, width, label='average prepare time')
rects3 = axs[1].bar(x + width, mean_send, width, label='average send time')

axs[1].set_xticklabels([0, 5, 10, 15, 20, 25, 30, 35, 40])
axs[1].set(xlabel='Requests Per Second', ylabel='Time (S)', title='Service time under varing request rates')
def autolabel(rects):
    for rect in rects:
        h = rect.get_height()
        axs[1].text(rect.get_x()+rect.get_width()/2., 1.05*h, '%d'%int(h),
                ha='center', va='bottom')
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
axs[1].legend()
fig.tight_layout()
plt.show()
